# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

klines = pd.read_csv('resource/dataset/binance/klines-BTCUSDT-1m_0413.csv')
train,test = train_test_split(klines,test_size=0.2)

# %%
klines2 = pd.read_csv('resource/dataset/binance/klines-BTCUSDT-1m_0415.csv')
train2,test2 = train_test_split(klines2,test_size=0.2)
y_train2 = train2.pop('close')
y_test2 = test2.pop('close')
del train2['openTime']
del train2['closeTime']
del train2['ignore']
del test2['openTime']
del test2['closeTime']
del test2['ignore']
y_train2 = y_train2.to_numpy()
y_test2 = y_test2.to_numpy()

x_train2 = train2.to_numpy()
x_test2 = test2.to_numpy()

# %%
klines3 = pd.read_csv('resource/dataset/binance/klines-BTCUSDT-1m_0409.csv')
train3,test3 = train_test_split(klines3,test_size=0.2)
y_train3 = train3.pop('close')
y_test3 = test3.pop('close')
del train3['openTime']
del train3['closeTime']
del train3['ignore']
del test3['openTime']
del test3['closeTime']
del test3['ignore']
y_train3 = y_train3.to_numpy()
y_test3 = y_test3.to_numpy()

x_train3 = train3.to_numpy()
x_test3 = test3.to_numpy()

# %%
klines3
# Out:
#         openTime      open      high       low     close    volume  \
# 0  1649462400000  42252.02  42272.93  42223.23  42272.92  51.23951
#
#        closeTime  quoteAssetVolume  numberOfTrades  takerBuyBaseAssetVolume  \
# 0  1649462459999      2.164448e+06            1009                 30.93579
#
#    takerBuyQuoteAssetVolume  ignore
# 0              1.306786e+06       0

# %%
klines4 = pd.read_csv('resource/dataset/binance/klines-BTCUSDT-1m_0407.csv')
train4,test4 = train_test_split(klines4,test_size=0.2)
y_train4 = train4.pop('close')
y_test4 = test4.pop('close')
del train4['openTime']
del train4['closeTime']
del train4['ignore']
del test4['openTime']
del test4['closeTime']
del test4['ignore']
y_train4 = y_train4.to_numpy()
y_test4 = y_test4.to_numpy()

x_train4 = train4.to_numpy()
x_test4 = test4.to_numpy()

# %%
y_train = train.pop('close')
y_test = test.pop('close')

# %%
del train['openTime']
del train['closeTime']
del train['ignore']
del test['openTime']
del test['closeTime']
del test['ignore']

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

x_train = train.to_numpy()
x_test = test.to_numpy()

# %%
import tensorflow as tf

model = tf.keras.models.load_model("resource/model/regression_20220415.h5")
# Out:
# 2022-04-18 11:38:32.212387: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf

# w_1 = tf.Variable(tf.random.normal([1]))
# w_2 = tf.Variable(tf.random.normal([1]))
# w_3 = tf.Variable(tf.random.normal([1]))
# b = tf.Variable(tf.random.normal([1]))

model = tf.keras.models.Sequential()

# model.add(tf.keras.layers.Dense(8, input_dim= 8, activation='relu'))
model.add(tf.keras.layers.Dense(64, input_dim= 8, activation='relu'))
model.add(tf.keras.layers.Dense(8, activation='relu'))
# model.add(tf.keras.layers.Dense(32, activation='relu'))
# model.add(tf.keras.layers.Dense(128, activation='relu'))
# model.add(tf.keras.layers.Dense(64, activation='relu'))
# model.add(tf.keras.layers.Dense(32, activation='relu'))
# model.add(tf.keras.layers.Dense(4, activation='relu'))
# model.add(tf.keras.layers.Dense(2, activation='relu'))
model.add(tf.keras.layers.Dense(1))

# hypothesis = (x_train['open']*w_1)+(x_train['high']*w_2)+(x_train['low']*w_3)+b
# cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_25 (Dense)            (None, 30)                270
#
#  dense_26 (Dense)            (None, 6)                 186
#
#  dense_27 (Dense)            (None, 1)                 7
#
# ...
# Total params: 463
# Trainable params: 463
# Non-trainable params: 0
# _________________________________________________________________

# %%
# sgd = tf.keras.optimizers.Adam(learning_rate=0.00000001)
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])
# model.compile(loss='mse',optimizer=sgd,metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=2000,verbose=1,batch_size=10)
# Out:
# Epoch 1/2000
# 80/80 [==============================] - 0s 754us/step - loss: 693.7869 - accuracy: 0.0000e+00
# Epoch 2/2000
# 80/80 [==============================] - 0s 750us/step - loss: 1308.9672 - accuracy: 0.0000e+00
# Epoch 3/2000
# 80/80 [==============================] - 0s 759us/step - loss: 1014.2014 - accuracy: 0.0000e+00
# Epoch 4/2000
# 80/80 [==============================] - 0s 747us/step - loss: 1557.3271 - accuracy: 0.0000e+00
# Epoch 5/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 43062.1914 - accuracy: 0.0000e+00
# Epoch 6/2000
# 80/80 [==============================] - 0s 807us/step - loss: 6877.9727 - accuracy: 0.0000e+00
# Epoch 7/2000
# 80/80 [==============================] - 0s 847us/step - loss: 17961.7891 - accuracy: 0.0000e+00
# Epoch 8/2000
# 80/80 [==============================] - 0s 751us/step - loss: 4537.5679 - accuracy: 0.0000e+00
# Epoch 9/2000
# ...

# %%
history = model.fit(x_train2,y_train2,epochs=2000,verbose=1,batch_size=10)
# Out:
# Epoch 1/2000
# 80/80 [==============================] - 0s 680us/step - loss: 5430.0088 - accuracy: 0.0000e+00
# Epoch 2/2000
# 80/80 [==============================] - 0s 654us/step - loss: 2581.7063 - accuracy: 0.0000e+00
# Epoch 3/2000
# 80/80 [==============================] - 0s 631us/step - loss: 1372.2717 - accuracy: 0.0000e+00
# Epoch 4/2000
# 80/80 [==============================] - 0s 698us/step - loss: 217.4282 - accuracy: 0.0000e+00
# Epoch 5/2000
# 80/80 [==============================] - 0s 792us/step - loss: 698.2991 - accuracy: 0.0000e+00
# Epoch 6/2000
# 80/80 [==============================] - 0s 764us/step - loss: 689.5944 - accuracy: 0.0000e+00
# Epoch 7/2000
# 80/80 [==============================] - 0s 746us/step - loss: 629.0197 - accuracy: 0.0000e+00
# Epoch 8/2000
# 80/80 [==============================] - 0s 877us/step - loss: 313.9870 - accuracy: 0.0000e+00
# Epoch 9/2000
# ...

# %%
history = model.fit(x_train3,y_train3,epochs=2000,verbose=1,batch_size=10)
# Out:
# Epoch 1/2000
# 80/80 [==============================] - 0s 777us/step - loss: 86540.7266 - accuracy: 0.0000e+00
# Epoch 2/2000
# 80/80 [==============================] - 0s 791us/step - loss: 52796.7148 - accuracy: 0.0000e+00
# Epoch 3/2000
# 80/80 [==============================] - 0s 618us/step - loss: 90897.7109 - accuracy: 0.0000e+00
# Epoch 4/2000
# 80/80 [==============================] - 0s 674us/step - loss: 48987.0195 - accuracy: 0.0000e+00
# Epoch 5/2000
# 80/80 [==============================] - 0s 773us/step - loss: 654.8905 - accuracy: 0.0000e+00
# Epoch 6/2000
# 80/80 [==============================] - 0s 737us/step - loss: 174.1609 - accuracy: 0.0000e+00
# Epoch 7/2000
# 80/80 [==============================] - 0s 763us/step - loss: 588.9329 - accuracy: 0.0000e+00
# Epoch 8/2000
# 80/80 [==============================] - 0s 750us/step - loss: 584.9182 - accuracy: 0.0000e+00
# Epoch 9/2000
# ...

# %%
history = model.fit(x_train4,y_train4,epochs=2000,verbose=1,batch_size=10)
# Out:
# Epoch 1/2000
# 80/80 [==============================] - 0s 859us/step - loss: 37011.9492 - accuracy: 0.0000e+00
# Epoch 2/2000
# 80/80 [==============================] - 0s 908us/step - loss: 78474.5781 - accuracy: 0.0000e+00
# Epoch 3/2000
# 80/80 [==============================] - 0s 849us/step - loss: 1210.8519 - accuracy: 0.0000e+00
# Epoch 4/2000
# 80/80 [==============================] - 0s 872us/step - loss: 1611.5468 - accuracy: 0.0000e+00
# Epoch 5/2000
# 80/80 [==============================] - 0s 1ms/step - loss: 1597.6708 - accuracy: 0.0000e+00
# Epoch 6/2000
# 80/80 [==============================] - 0s 828us/step - loss: 9087.6055 - accuracy: 0.0000e+00
# Epoch 7/2000
# 80/80 [==============================] - 0s 868us/step - loss: 2267.0142 - accuracy: 0.0000e+00
# Epoch 8/2000
# 80/80 [==============================] - 0s 806us/step - loss: 1552.5168 - accuracy: 0.0000e+00
# Epoch 9/2000
# ...

# %%
# 4. 평가 예측
loss, mse = model.evaluate(x_test, y_test, batch_size=1)
# Out:
# 200/200 [==============================] - 0s 965us/step - loss: 2262.5010 - accuracy: 0.0000e+00

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# array([[39619.81 ],
#        [40014.043],
#        [39506.016],
#        [39655.402],
#        [40280.277],
#        [39954.246],
#        [40317.355],
#        [40369.926],
#        [39767.492],
#        [40317.8  ],
#        [39785.73 ],
#        [39702.035],
#        [40395.316],
#        [39960.05 ],
#        [40476.91 ],
#        [39517.12 ],
#        [40204.117],
#        [40022.277],
#        [39956.555],
#        [40530.723],
#        [39825.074],
#        [40191.004],
#        [39594.96 ],
#        [40100.094],
#        [40443.58 ],
#        [40030.94 ],
#        [40181.934],
#        [40579.3  ],
#        [40297.484],
#        [40131.52 ],
#        [40294.59 ],
#        [39797.33 ],
#        [40084.047],
#        [40285.594],
#        [39676.023],
#        [40031.953],
#        [40225.258],
#        [39710.355],
#        [40503.996],
#        [40193.254],
#        [40147.586],
#        [39966.164],
#        [40362.766],
#        [39554.875],
#        [39643.36 ],
# ...

# %%
# Calling `save('my_model.h5')` creates a h5 file `my_model.h5`.
model.save("regression_20220415.h5")

# It can be used to reconstruct the model identically.
# reconstructed_model = keras.models.load_model("my_h5_model.h5")
